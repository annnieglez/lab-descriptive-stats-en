# %% [markdown]
# # Before you start :
#    - These exercises are related to the Subsetting and Descriptive Stats lessons.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# #### Import all the libraries that are necessary

# %%
# import libraries here
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### In this challenge we will use the `Temp_States.csv` file.
#
# #### First import it into a data frame called `temp`.

# %%
# YOUR CODE HERE
temp = pd.read_csv('Temp_States.csv')

# %% [markdown]
# #### Print `temp`

# %%
# your solution here
temp.head(10)
# Out:
#          City        State  Temperature
# 0         NYC     New York    19.444444
# 1      Albany     New York     9.444444
# 2     Buffalo     New York     3.333333
# 3    Hartford  Connecticut    17.222222
# 4  Bridgeport  Connecticut    14.444444
# 5      Treton   New Jersey    22.222222
# 6      Newark   New Jersey    20.000000

# %% [markdown]
# #### Explore the data types of the Temp dataframe. What type of data do we have? Comment your result.

# %%
# YOUR CODE HERE
print(temp.dtypes)
# Out:
# City            object
# State           object
# Temperature    float64
# dtype: object

# %% [markdown]
# #### Select the rows where state is New York

# %%
# YOUR CODE HERE
temp[temp["State"] == "New York"]
# Out:
#       City     State  Temperature
# 0      NYC  New York    19.444444
# 1   Albany  New York     9.444444
# 2  Buffalo  New York     3.333333

# %% [markdown]
# #### What is the average of the temperature of cities in New York?

# %%
# YOUR CODE HERE
temp[temp["State"] == "New York"]["Temperature"].mean()
# Out:
# np.float64(10.74074074074074)

# %% [markdown]
# #### We want to know cities and states with Temperature above 15 degress Celcius

# %%
# your answer here
temp[temp["Temperature"] > 15]
# Out:
#        City        State  Temperature
# 0       NYC     New York    19.444444
# 3  Hartford  Connecticut    17.222222
# 5    Treton   New Jersey    22.222222
# 6    Newark   New Jersey    20.000000

# %% [markdown]
# #### Now, return only the cities that have a temperature above 15 degress Celcius

# %%
# YOUR CODE HERE
temp[temp["Temperature"] > 15]["City"]
# Out:
# 0         NYC
# 3    Hartford
# 5      Treton
# 6      Newark
# Name: City, dtype: object

# %% [markdown]
# #### We want to know which cities have a temperature above 15 degrees Celcius and below 20 degrees Celcius
#
# *Hint: First write the condition then select the rows.*

# %%
# YOUR CODE HERE
temp[(temp["Temperature"] > 15) & (temp["Temperature"] < 20)]["City"]
# Out:
# 0         NYC
# 3    Hartford
# Name: City, dtype: object

# %%
temp['State'].value_counts()
# Out:
# State
# New York       3
# Connecticut    2
# New Jersey     2
# Name: count, dtype: int64

# %% [markdown]
# #### Find the mean and the standard deviation of the temperature of each state.
#
# *Hint: Use functions from Data Manipulation lesson*

# %%
# YOUR CODE HERE
temp.groupby(['State'], observed=False)['Temperature'].agg(['mean', 'std']).reset_index()
# Out:
#          State       mean       std
# 0  Connecticut  15.833333  1.964186
# 1   New Jersey  21.111111  1.571348
# 2     New York  10.740741  8.133404

# %% [markdown]
# # Challenge 2

# %% [markdown]
# #### Load the `employee.csv` file into a DataFrame. Call the dataframe `employee`

# %%
# YOUR CODE HERE
emp = pd.read_csv('Employee.csv')

# %%
emp.head(15)
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 0    Jose         IT  Bachelor      M    analyst      1      35
# 1   Maria         IT    Master      F    analyst      2      30
# 2   David         HR    Master      M    analyst      2      30
# 3   Sonia         HR  Bachelor      F    analyst      4      35
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 6  Carlos         IT    Master      M         VP      8      70
# 7   Pedro         IT       Phd      M  associate      7      60
# 8     Ana         HR    Master      F         VP      8      70

# %% [markdown]
# #### Explore the data types of the Temp dataframe. Comment your results

# %%
# YOUR CODE HERE
print(emp.dtypes)
# Out:
# Name          object
# Department    object
# Education     object
# Gender        object
# Title         object
# Years          int64
# Salary         int64
# dtype: object

# %% [markdown]
# #### Show visually the frequency distribution (histogram) of the employee dataset. In few words describe these histograms?

# %%
# your answer here

# Creating subplots for both histograms
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Histogram for Years of Experience
sns.histplot(emp["Years"], bins=8, kde=True, ax=axes[0], color="blue")
axes[0].set_title("Distribution of Years of Experience")
axes[0].set_xlabel("Years")
axes[0].set_ylabel("Frequency")

# Histogram for Salary
sns.histplot(emp["Salary"], bins=8, kde=True, ax=axes[1], color="green")
axes[1].set_title("Distribution of Salaries")
axes[1].set_xlabel("Salary")
axes[1].set_ylabel("Frequency")

plt.tight_layout()
plt.show()

# %% [markdown]
# #### What's the average salary in this company?

# %%
# YOUR CODE HERE
emp["Salary"].mean()
# Out:
# np.float64(48.888888888888886)

# %% [markdown]
# #### What's the highest salary?

# %%
# YOUR CODE HERE
emp["Salary"].max()
# Out:
# np.int64(70)

# %% [markdown]
# #### What's the lowest salary?

# %%
# YOUR CODE HERE
emp["Salary"].min()
# Out:
# np.int64(30)

# %% [markdown]
# #### Who are the employees with the lowest salary?

# %%
# YOUR CODE HERE
emp[emp["Salary"] == emp["Salary"].min()]["Name"]
# Out:
# 1    Maria
# 2    David
# Name: Name, dtype: object

# %% [markdown]
# #### Could you give all the information about an employee called David?

# %%
# YOUR CODE HERE
emp[emp["Name"] == "David"]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Could you give only David's salary?

# %%
# YOUR CODE HERE
emp[emp["Name"] == "David"]["Salary"]
# Out:
# 2    30
# Name: Salary, dtype: int64

# %% [markdown]
# #### Print all the rows where job title is associate

# %%
# YOUR CODE HERE
emp[emp["Title"] == "associate"]
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 7   Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Print the first 3 rows of your dataframe
#
# ##### Tip : There are 2 ways to do it. Do it both ways

# %%
# YOUR CODE HERE
emp.head(3)
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %%
print(emp.iloc[:3])
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %%
# YOUR CODE HERE
print(emp.loc[:2])
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Find the employees who's title is associate and the salary above 55?

# %%
# YOUR CODE HERE
emp[(emp["Title"] == "associate") & (emp["Salary"] > 55)]
# Out:
#     Name Department Education Gender      Title  Years  Salary
# 7  Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Group the employees based on their number of years of employment. What are the average salaries in each group?

# %%
# YOUR CODE HERE
emp.groupby(['Years'])['Salary'].mean().reset_index(name='Average')
# Out:
#    Years    Average
# 0      1  35.000000
# 1      2  38.333333
# 2      3  55.000000
# 3      4  35.000000
# 4      7  60.000000
# 5      8  70.000000

# %% [markdown]
# ####  What is the average Salary per title?

# %%
# YOUR CODE HERE
emp.groupby(['Title'])['Salary'].mean().reset_index(name='Average')
# Out:
#        Title    Average
# 0         VP  70.000000
# 1    analyst  32.500000
# 2  associate  56.666667

# %% [markdown]
# #### Show a visual summary of the data using boxplot. What Are the First and Third Quartiles? Comment your results.
#
# * Hint : Quantiles vs Quartiles*
# In Probability and Statistics, quantiles are cut points dividing the range of a probability distribution into continuous intervals with equal probabilities. When division is into four parts the values of the variate corresponding to 25%, 50% and 75% of the total distribution are called quartiles.

# %%
# YOUR CODE HERE
# Plot Boxplot
plt.figure(figsize=(6, 4))
sns.boxplot(y=emp['Salary'], color="Purple")
plt.title("Salary Distribution Boxplot")
plt.ylabel("Salary")
plt.show()

# %%
# print first quartile here
Q1 = emp['Salary'].quantile(0.25) 
print("First Quartile (Q1):", Q1)
# Out:
# First Quartile (Q1): 35.0

# %%
# print third quartile here
Q3 = emp['Salary'].quantile(0.75) 
print("First Quartile (Q3):", Q3)
# Out:
# First Quartile (Q3): 60.0

# %% [markdown]
# #### Is the mean salary per gender different?

# %%
# your answer here
emp.groupby(['Gender'])['Salary'].mean().reset_index(name='Average')
# Out:
#   Gender  Average
# 0      F     47.5
# 1      M     50.0

# %% [markdown]
# #### Find the minimum, mean and the maximum of all numeric columns for each Department.
#
# ##### Hint: Use functions from Data Manipulation lesson

# %%
# your answer here
department_stats = emp.groupby('Department').agg({
    'Salary': ['min', 'mean', 'max'],
    'Years': ['min', 'mean', 'max']
}).reset_index()

department_stats
# Out:
#   Department Salary            Years
#                 min   mean max   min      mean max
# 0         HR     30  45.00  70     2  4.666667   8
# 1         IT     30  48.75  70     1  4.500000   8
# 2      Sales     55  55.00  55     2  2.500000   3

# %% [markdown]
# ### Bonus Question
#
# #### For each department, compute the difference between the maximal salary and the minimal salary.
#
# ##### * Hint: try using `agg` or `apply` and `lambda`*

# %%
# your answer here
department_salary_diff = emp.groupby('Department').agg({
    'Salary': lambda x: x.max() - x.min()
}).reset_index(names = ['Department', 'Salary difference'])

print(department_salary_diff)
# Out:
#   Department  Salary
# 0         HR      40
# 1         IT      40
# 2      Sales       0

# %% [markdown]
# # Challenge 3

# %% [markdown]
# #### Open the Orders.csv dataset. Name your dataset orders

# %%
# your answer here
ord = pd.read_csv('Orders.csv')

# %% [markdown]
# #### Explore your dataset by looking at the data types and the summary statistics. Comment your results

# %%
# your answer here
ord.dtypes
# Out:
# Unnamed: 0        int64
# InvoiceNo         int64
# StockCode        object
# year              int64
# month             int64
# day               int64
# hour              int64
# Description      object
# Quantity          int64
# InvoiceDate      object
# UnitPrice       float64
# CustomerID        int64
# Country          object
# amount_spent    float64
# dtype: object

# %%
ord.head(5)
# Out:
#    Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0           0     536365    85123A  2010     12    3     8
# 1           1     536365     71053  2010     12    3     8
# 2           2     536365    84406B  2010     12    3     8
# 3           3     536365    84029G  2010     12    3     8
# 4           4     536365    84029E  2010     12    3     8
#
#                            Description  Quantity          InvoiceDate  \
# 0   white hanging heart t-light holder         6  2010-12-01 08:26:00
# 1                  white metal lantern         6  2010-12-01 08:26:00
# 2       cream cupid hearts coat hanger         8  2010-12-01 08:26:00
# 3  knitted union flag hot water bottle         6  2010-12-01 08:26:00
# 4       red woolly hottie white heart.         6  2010-12-01 08:26:00
#
#    UnitPrice  CustomerID         Country  amount_spent
# 0       2.55       17850  United Kingdom         15.30
# 1       3.39       17850  United Kingdom         20.34
# ...

# %%
# your answer here
ord.describe().T
# Out:
#                  count           mean            std       min        25%  \
# Unnamed: 0    397924.0  278465.221859  152771.368303       0.0  148333.75
# InvoiceNo     397924.0  560617.126645   13106.167695  536365.0  549234.00
# year          397924.0    2010.934259       0.247829    2010.0    2011.00
# month         397924.0       7.612537       3.416527       1.0       5.00
# day           397924.0       3.614555       1.928274       1.0       2.00
# hour          397924.0      12.728247       2.273535       6.0      11.00
# Quantity      397924.0      13.021823     180.420210       1.0       2.00
# UnitPrice     397924.0       3.116174      22.096788       0.0       1.25
# CustomerID    397924.0   15294.315171    1713.169877   12346.0   13969.00
# amount_spent  397924.0      22.394749     309.055588       0.0       4.68
#
#                     50%        75%        max
# Unnamed: 0    284907.50  410079.25  541908.00
# InvoiceNo     561893.00  572090.00  581587.00
# ...

# %% [markdown]
# ####  What is the average Purchase Price?

# %%
# your answer here
ord.UnitPrice.mean()
# Out:
# np.float64(3.1161744805540756)

# %% [markdown]
# #### What were the highest and lowest purchase prices?

# %%
# your answer here
ord.UnitPrice.max()
# Out:
# np.float64(8142.75)

# %%
# your answer here
ord.UnitPrice.min()
# Out:
# np.float64(0.0)

# %% [markdown]
# #### Select all the customers we have in Spain

# %%
# your answer here
ord[ord["Country"] == "Spain"]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 4250          6421     536944     22383  2010     12    5    12
# 4251          6422     536944     22384  2010     12    5    12
# 4252          6423     536944     20727  2010     12    5    12
# 4253          6424     536944     20725  2010     12    5    12
# 4254          6425     536944     20728  2010     12    5    12
# ...            ...        ...       ...   ...    ...  ...   ...
# 394733      535271     581193     23291  2011     12    3    17
# 394734      535272     581193    85232D  2011     12    3    17
# 394735      535273     581193     22721  2011     12    3    17
# 394736      535274     581193     23241  2011     12    3    17
# 394737      535275     581193     23247  2011     12    3    17
#
#                           Description  Quantity          InvoiceDate  \
# 4250          lunch bag suki  design         70  2010-12-03 12:20:00
# ...

# %% [markdown]
# #### How many customers do we have in Spain?
# ##### Hint : Use value_counts()

# %%
# your answer here
customers_in_spain = ord['Country'].value_counts().get('Spain', 0)
customers_in_spain
# Out:
# np.int64(2485)

# %% [markdown]
# #### Select all the customers who have bought more than 50 items ?

# %%
# your answer here
customers_more_than_50_items = ord.groupby('CustomerID')['Quantity'].sum()
filtered_customers = ord[ord['CustomerID'].isin(customers_more_than_50_items.index)]
filtered_customers
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0                0     536365    85123A  2010     12    3     8
# 1                1     536365     71053  2010     12    3     8
# 2                2     536365    84406B  2010     12    3     8
# 3                3     536365    84029G  2010     12    3     8
# 4                4     536365    84029E  2010     12    3     8
# ...            ...        ...       ...   ...    ...  ...   ...
# 397919      541904     581587     22613  2011     12    5    12
# 397920      541905     581587     22899  2011     12    5    12
# 397921      541906     581587     23254  2011     12    5    12
# 397922      541907     581587     23255  2011     12    5    12
# 397923      541908     581587     22138  2011     12    5    12
#
#                                 Description  Quantity          InvoiceDate  \
# 0        white hanging heart t-light holder         6  2010-12-01 08:26:00
# ...

# %% [markdown]
# #### Select orders from Spain that are above 50 items

# %%
# your answer here
customers_from_Spain = ord[ord["Country"] == "Spain"]
filtered_customers = ord[ord['CustomerID'].isin(customers_from_Spain['CustomerID'])]
filtered_customers
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 4250          6421     536944     22383  2010     12    5    12
# 4251          6422     536944     22384  2010     12    5    12
# 4252          6423     536944     20727  2010     12    5    12
# 4253          6424     536944     20725  2010     12    5    12
# 4254          6425     536944     20728  2010     12    5    12
# ...            ...        ...       ...   ...    ...  ...   ...
# 394733      535271     581193     23291  2011     12    3    17
# 394734      535272     581193    85232D  2011     12    3    17
# 394735      535273     581193     22721  2011     12    3    17
# 394736      535274     581193     23241  2011     12    3    17
# 394737      535275     581193     23247  2011     12    3    17
#
#                           Description  Quantity          InvoiceDate  \
# 4250          lunch bag suki  design         70  2010-12-03 12:20:00
# ...

# %% [markdown]
# #### Select all free orders

# %%
# your answer here
ord[ord["UnitPrice"] == 0]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 6914          9302     537197     22841  2010     12    7    14
# 22539        33576     539263     22580  2010     12    4    14
# 25379        40089     539722     22423  2010     12    2    13
# 29080        47068     540372     22090  2011      1    4    16
# 29082        47070     540372     22553  2011      1    4    16
# 34494        56674     541109     22168  2011      1    4    15
# 53788        86789     543599    84535B  2011      2    4    13
# 85671       130188     547417     22062  2011      3    3    10
# 92875       139453     548318     22055  2011      3    3    12
# 97430       145208     548871     22162  2011      4    1    14
# 107192      157042     550188     22636  2011      4    4    18
# 128641      187613     553000     47566  2011      5    4    15
# 137127      198383     554037     22619  2011      5    5    14
# 194648      279324     561284     22167  2011      7    2    12
# ...

# %% [markdown]
# #### Select all orders that are 'lunch bag'
# #### Hint: Use string functions

# %%
# your answer here
ord[ord['Description'].str.contains('lunch bag', case=False, na=False)]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 93              93     536378     20725  2010     12    3     9
# 172            174     536385     22662  2010     12    3     9
# 354            363     536401     22662  2010     12    3    11
# 359            368     536401     20725  2010     12    3    11
# 360            369     536401     22382  2010     12    3    11
# ...            ...        ...       ...   ...    ...  ...   ...
# 397465      540436     581486     23207  2011     12    5     9
# 397713      541695     581538     20727  2011     12    5    11
# 397714      541696     581538     20725  2011     12    5    11
# 397877      541862     581581     23681  2011     12    5    12
# 397880      541865     581583     20725  2011     12    5    12
#
#                         Description  Quantity          InvoiceDate  UnitPrice  \
# 93          lunch bag red retrospot        10  2010-12-01 09:37:00       1.65
# ...

# %% [markdown]
# #### Select all orders that are made in 2011 and are 'lunch bag'

# %%
# your answer here
ord[(ord['Description'].str.contains('lunch bag', case=False, na=False)) & (ord["year"] == 2011)]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 26340        42678     540015     20725  2011      1    2    11
# 26341        42679     540015     20726  2011      1    2    11
# 26512        42851     540023     22382  2011      1    2    12
# 26513        42852     540023     20726  2011      1    2    12
# 26860        43616     540098     22384  2011      1    2    15
# ...            ...        ...       ...   ...    ...  ...   ...
# 397465      540436     581486     23207  2011     12    5     9
# 397713      541695     581538     20727  2011     12    5    11
# 397714      541696     581538     20725  2011     12    5    11
# 397877      541862     581581     23681  2011     12    5    12
# 397880      541865     581583     20725  2011     12    5    12
#
#                         Description  Quantity          InvoiceDate  UnitPrice  \
# 26340       lunch bag red retrospot        10  2011-01-04 11:40:00       1.65
# ...

# %% [markdown]
# #### Show the frequency distribution of the amount spent in Spain.

# %%
# your answer here
spain_ord = ord[ord["Country"] == "Spain"]

plt.hist(spain_ord["amount_spent"], bins=100, color='Purple')
plt.title('Frequency Distribution of Amount Spent in Spain')
plt.xlabel('Amount Spent')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# #### Select all orders made in the month of August

# %%
# your answer here
aug_ord = ord[ord["month"] == 8]
aug_ord
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 199475      285421     561904     22075  2011      8    1     8
# 199476      285422     561904    85049E  2011      8    1     8
# 199477      285423     561905     21385  2011      8    1     9
# 199478      285424     561905    84970L  2011      8    1     9
# 199479      285425     561905    84970S  2011      8    1     9
# ...            ...        ...       ...   ...    ...  ...   ...
# 226483      320688     565067     22644  2011      8    3    17
# 226484      320689     565067     22645  2011      8    3    17
# 226485      320690     565067     22637  2011      8    3    17
# 226486      320691     565067     22646  2011      8    3    17
# 226487      320692     565067     22741  2011      8    3    17
#
#                                 Description  Quantity          InvoiceDate  \
# 199475         6 ribbons elegant christmas         96  2011-08-01 08:30:00
# ...

# %% [markdown]
# #### Select how many orders are made by countries in the month of August
# ##### Hint: Use value_counts()

# %%
# your answer here
ord[ord["month"] == 8].groupby(["Country"])["Quantity"].size().reset_index(name = "Count")
# Out:
#             Country  Count
# 0         Australia    107
# 1           Austria     88
# 2           Belgium    194
# 3            Canada      5
# 4   Channel Islands    140
# 5           Denmark     16
# 6              EIRE    593
# 7           Finland     61
# 8            France    569
# 9           Germany    795
# 10          Iceland     22
# 11           Israel    171
# 12            Italy     95
# 13            Malta     55
# 14      Netherlands    280
# 15           Norway     77
# 16           Poland     17
# 17         Portugal     41
# 18            Spain    252
# 19           Sweden     40
# 20      Switzerland    267
# 21   United Kingdom  23105
# 22      Unspecified     23

# %%
ord[ord["month"] == 8]['Country'].value_counts().reset_index(name = "Count")
# Out:
#             Country  Count
# 0    United Kingdom  23105
# 1           Germany    795
# 2              EIRE    593
# 3            France    569
# 4       Netherlands    280
# 5       Switzerland    267
# 6             Spain    252
# 7           Belgium    194
# 8            Israel    171
# 9   Channel Islands    140
# 10        Australia    107
# 11            Italy     95
# 12          Austria     88
# 13           Norway     77
# 14          Finland     61
# 15            Malta     55
# 16         Portugal     41
# 17           Sweden     40
# 18      Unspecified     23
# 19          Iceland     22
# 20           Poland     17
# 21          Denmark     16
# 22           Canada      5

# %% [markdown]
# #### What's the  average amount of money spent by country

# %%
# your answer here
ord[ord["month"] == 8].groupby(["Country"])["amount_spent"].mean().reset_index(name = "Average")
# Out:
#             Country     Average
# 0         Australia  210.179439
# 1           Austria   17.228182
# 2           Belgium   18.319691
# 3            Canada   10.312000
# 4   Channel Islands   34.977000
# 5           Denmark   13.321875
# 6              EIRE   28.612782
# 7           Finland   22.565574
# 8            France   24.272337
# 9           Germany   24.177069
# 10          Iceland   26.586818
# 11           Israel   28.501813
# 12            Italy   20.957368
# 13            Malta   20.345455
# 14      Netherlands  144.027893
# 15           Norway   26.309221
# 16           Poland   23.635294
# 17         Portugal   29.790244
# 18            Spain   13.281389
# 19           Sweden   35.021500
# 20      Switzerland   18.613820
# 21   United Kingdom   21.573396
# 22      Unspecified   23.088261

# %% [markdown]
# #### What's the most expensive item?

# %%
ord.head(5)
# Out:
#    Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0           0     536365    85123A  2010     12    3     8
# 1           1     536365     71053  2010     12    3     8
# 2           2     536365    84406B  2010     12    3     8
# 3           3     536365    84029G  2010     12    3     8
# 4           4     536365    84029E  2010     12    3     8
#
#                            Description  Quantity          InvoiceDate  \
# 0   white hanging heart t-light holder         6  2010-12-01 08:26:00
# 1                  white metal lantern         6  2010-12-01 08:26:00
# 2       cream cupid hearts coat hanger         8  2010-12-01 08:26:00
# 3  knitted union flag hot water bottle         6  2010-12-01 08:26:00
# 4       red woolly hottie white heart.         6  2010-12-01 08:26:00
#
#    UnitPrice  CustomerID         Country  amount_spent
# 0       2.55       17850  United Kingdom         15.30
# 1       3.39       17850  United Kingdom         20.34
# ...

# %%
# your answer here
ord[ord["amount_spent"] == ord["amount_spent"].max()]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 397451      540421     581483     23843  2011     12    5     9
#
#                         Description  Quantity          InvoiceDate  UnitPrice  \
# 397451  paper craft , little birdie     80995  2011-12-09 09:15:00       2.08
#
#         CustomerID         Country  amount_spent
# 397451       16446  United Kingdom      168469.6

# %% [markdown]
# #### What was the average amount spent per year ?

# %%
# your answer here
ord.groupby(["year"])["amount_spent"].mean().reset_index(name = "Average")
# Out:
#    year    Average
# 0  2010  21.892733
# 1  2011  22.430074
